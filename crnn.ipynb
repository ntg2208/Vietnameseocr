# %%
from google.colab import drive
drive.mount('/content/gdrive')

import os

os.chdir("gdrive/My Drive/Playground")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from sklearn.model_selection import KFold
import keras
from keras.models import Sequential
from keras.layers import Input, Dense, Activation, Bidirectional, Dropout, MaxPooling2D
from keras.layers import Reshape, Lambda, BatchNormalization
from keras import applications
from keras.layers.recurrent import LSTM
from keras.layers.merge import add, concatenate
from keras.models import Model
from keras.optimizers import Adadelta, Adam
from keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from loader2 import TextImageGenerator, MAX_LEN, CHAR_DICT, SIZE, VizCallback, ctc_lambda_func, attention_rnn
import numpy as np
import tensorflow as tf
from keras import backend as K
import argparse
# Out:
# Using TensorFlow backend.

# %%
def maxpooling(base_model):
    model = Sequential(name='vgg16')
    for layer in base_model.layers[:-1]:
        if 'pool' in layer.name:
            pooling_layer = MaxPooling2D(pool_size=(2, 2), name=layer.name)
            model.add(pooling_layer)
        else:
            model.add(layer)
    return model

def get_model(input_shape, training, finetune):
    inputs = Input(name='the_inputs', shape=input_shape, dtype='float32')
    base_model = applications.VGG16(weights='imagenet', include_top=False)
    base_model = maxpooling(base_model)
    inner = base_model(inputs)

    inner = Reshape(target_shape=(int(inner.shape[1]), -1), name='reshape')(inner)
    inner = Dense(512, activation='relu', kernel_initializer='he_normal', name='dense1')(inner) 
    inner = Dropout(0.25)(inner) 
    inner = attention_rnn(inner)

    lstm1 = Bidirectional(LSTM(256, return_sequences=True, kernel_initializer='he_normal', name='lstm1', dropout=0.25, recurrent_dropout=0.25))(inner)
    lstm2 = Bidirectional(LSTM(256, return_sequences=True, kernel_initializer='he_normal', name='lstm2', dropout=0.25, recurrent_dropout=0.25))(lstm1)
    
    y_pred = Dense(CHAR_DICT, activation='softmax', kernel_initializer='he_normal',name='dense2')(lstm2)
    
    labels = Input(name='the_labels', shape=[MAX_LEN], dtype='float32')
    input_length = Input(name='input_length', shape=[1], dtype='int64')
    label_length = Input(name='label_length', shape=[1], dtype='int64')

    loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([y_pred, labels, input_length, label_length])

    
    y_func = K.function([inputs], [y_pred])
    
    if training:
        Model(inputs=[inputs, labels, input_length, label_length], outputs=loss_out).summary()
        return Model(inputs=[inputs, labels, input_length, label_length], outputs=loss_out), y_func
    else:
        return Model(inputs=[inputs], outputs=y_pred)

def train_kfold(idx, kfold, datapath, labelpath,  epochs, batch_size, lr, finetune, name):
    sess = tf.Session()
    K.set_session(sess)

    model, y_func = get_model((*SIZE, 3), training=True, finetune=finetune)
    ada = Adam(lr=lr)
    model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer=ada)

    ## load data
    train_idx, valid_idx = kfold[idx]
    train_generator = TextImageGenerator(datapath, labelpath, *SIZE, batch_size, 16, train_idx, True, MAX_LEN)
    train_generator.build_data()
    valid_generator  = TextImageGenerator(datapath, labelpath, *SIZE, batch_size, 16, valid_idx, False, MAX_LEN)
    valid_generator.build_data()

    ## callbacks
    weight_path = 'model/{}_{}.h5'.format(name, idx)
    ckp = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
    vis = VizCallback(sess, y_func, valid_generator, len(valid_idx))
    earlystop = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='min')

    if finetune:
        print('load pretrain model')
        model.load_weights(weight_path)

    model.fit_generator(generator=train_generator.next_batch(),
                    steps_per_epoch=int(len(train_idx) / batch_size),
                    epochs=epochs,
                    callbacks=[ckp, vis, earlystop],
                    validation_data=valid_generator.next_batch(),
                    validation_steps=int(len(valid_idx) / batch_size))

# %%
def train(datapath, labelpath, epochs, batch_size, lr, finetune=False, name='model'):
    nsplits = 5

    nfiles = np.arange(len(os.listdir(datapath)))

    kfold = list(KFold(nsplits, random_state=2018).split(nfiles))
    for idx in range(nsplits):
        train_kfold(idx, kfold, datapath, labelpath, epochs, batch_size, lr, finetune, name)

# %%
datapath = 'data/Address/'
labelpath = 'data/labels.json'
epochs = 60
batch_size = 3
lr = 0.001 
finetune = 0
name = 'best'

args = [datapath, labelpath, epochs, batch_size, lr, finetune, name]

train(datapath, labelpath, epochs, batch_size, lr, finetune, name)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4249: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4229: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# the_inputs (InputLayer)         (None, 1280, 64, 3)  0
# __________________________________________________________________________________________________
# vgg16 (Sequential)              multiple             14714688    the_inputs[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 80, 2048)     0           vgg16[1][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 80, 512)      1049088     reshape[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 80, 512)      0           dense1[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 512, 80)      0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512, 80)      6480        permute_1[0][0]
# __________________________________________________________________________________________________
# dim_reduction (Lambda)          (None, 80)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (None, 512, 80)      0           dim_reduction[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 80, 512)      0           repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# attention_mul (Multiply)        (None, 80, 512)      0           dropout_1[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 80, 512)      1574912     attention_mul[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 80, 512)      1574912     bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 80, 151)      77463       bidirectional_2[0][0]
# __________________________________________________________________________________________________
# the_labels (InputLayer)         (None, 70)           0
# __________________________________________________________________________________________________
# input_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# label_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           dense2[0][0]
#                                                                  the_labels[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 18,997,543
# Trainable params: 18,997,543
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 1458  Image Loading start...  data/Address/
# Image Loading finish...
# 365  Image Loading start...  data/Address/
# Image Loading finish...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1/60
# 486/486 [==============================] - 370s 761ms/step - loss: 200.3554 - val_loss: 195.5780
#
# Epoch 00001: val_loss improved from inf to 195.57796, saving model to model/best_0.h5
# label: 271 đường Đông Bắc, phường Tân Chánh Hiệp, Quận 12, TP Hồ Chí Minh     - predict:               Nh
# label: 121 Lê Niệm, Phường Phú Thạnh, Quận Tân phú, TP Hồ Chí Minh            - predict:               Nh
# label: Thôn Quý Khê, Xã Cẩm Hoàng, Huyện Cẩm Giàng, Hải Dương                 - predict:               Nh
#
# Out of 365 samples:  Mean edit distance: 55.989 Mean normalized edit distance: 0.800
# Epoch 2/60
# 486/486 [==============================] - 359s 738ms/step - loss: 188.0273 - val_loss: 182.1383
#
# Epoch 00002: val_loss improved from 195.57796 to 182.13829, saving model to model/best_0.h5
# label: Khóm 6, Thị Trấn Sông Đốc, Huyện Trần Văn Thời, Cà Mau                 - predict: Số               , Chí Minh
# label: 1/10/32 Trần Bình Trọng, Phường 5, Quận Bình Thạnh, TP Hồ Chí Minh     - predict: Số               , Chí Minh
# label: Số 161-163-165 Xuân Hồng, Phường 12, Quận Tân Bình, TP Hồ Chí Minh     - predict: Số               , Chí Minh
#
# Out of 365 samples:  Mean edit distance: 52.797 Mean normalized edit distance: 0.754
# Epoch 3/60
# 486/486 [==============================] - 361s 743ms/step - loss: 174.1353 - val_loss: 161.9136
#
# Epoch 00003: val_loss improved from 182.13829 to 161.91360, saving model to model/best_0.h5
# label: Số 219B, ấp Chánh, Xã Đức Lập Hạ, Huyện Đức Hoà, Long An               - predict:     , , , , , T, Chí Minh
# label: Thôn Nứa, Xã Liên Hiệp, Huyện Hưng Hà, Thái Bình                       - predict:     , , , , , T, Chí Minh
# label: 27 Lý Thái Tổ, Phường An Hòa, Thành phố Huế, Thừa Thiên - Huế          - predict:     , , , , , T, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 54.115 Mean normalized edit distance: 0.773
# Epoch 4/60
# 486/486 [==============================] - 358s 737ms/step - loss: 162.1616 - val_loss: 160.3856
#
# Epoch 00004: val_loss improved from 161.91360 to 160.38556, saving model to model/best_0.h5
# label: Số 6 Vũ Ngọc Phan, Phường Láng Hạ, Quận Đống đa, Hà Nội                - predict: 1    , , , ,  , P, Cà Minh
# label: 42-44, ấp Vĩnh Tiến, Thị Trấn Vĩnh Thạnh, Huyện Vĩnh Thạnh, Cần Thơ    - predict: 1    , , , ,  , P, Cà Minh
# label: Xóm Đoàn Kết, Xã Dương Liễu, Huyện Hoài Đức, Hà Nội                    - predict: 1    , , , ,  , P, Cà Minh
#
# Out of 365 samples:  Mean edit distance: 53.575 Mean normalized edit distance: 0.765
# Epoch 5/60
#   5/486 [..............................] - ETA: 5:22 - loss: 168.5847

# %%
nsplits = 5

nfiles = np.arange(len(os.listdir(datapath)))

kfold = list(KFold(nsplits, random_state=2018).split(nfiles))
idx = 0
train_kfold(idx, kfold, datapath, labelpath, epochs, batch_size, lr, finetune, name)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# the_inputs (InputLayer)         (None, 1280, 64, 3)  0
# __________________________________________________________________________________________________
# vgg16 (Sequential)              multiple             14714688    the_inputs[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 80, 2048)     0           vgg16[1][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 80, 512)      1049088     reshape[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 80, 512)      0           dense1[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 512, 80)      0           dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512, 80)      6480        permute_2[0][0]
# __________________________________________________________________________________________________
# dim_reduction (Lambda)          (None, 80)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# repeat_vector_2 (RepeatVector)  (None, 512, 80)      0           dim_reduction[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 80, 512)      0           repeat_vector_2[0][0]
# __________________________________________________________________________________________________
# attention_mul (Multiply)        (None, 80, 512)      0           dropout_2[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 80, 512)      1574912     attention_mul[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 80, 512)      1574912     bidirectional_3[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 80, 151)      77463       bidirectional_4[0][0]
# __________________________________________________________________________________________________
# the_labels (InputLayer)         (None, 70)           0
# __________________________________________________________________________________________________
# input_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# label_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           dense2[0][0]
#                                                                  the_labels[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 18,997,543
# Trainable params: 18,997,543
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 1458  Image Loading start...  data/Address/
# Image Loading finish...
# 365  Image Loading start...  data/Address/
# Image Loading finish...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1/60
# 486/486 [==============================] - 578s 1s/step - loss: 201.1673 - val_loss: 193.8250
#
# Epoch 00001: val_loss improved from inf to 193.82497, saving model to model/best_0.h5
# label: 75 Thái Phiên, Phường Tây Lộc, Thành Phố Huế, Thừa Thiên - Huế         - predict:                 n
# label: Số 118 Quốc lộ 1A, Khóm 3, Phường 10, Thành phố Sóc Trăng, Sóc Trăng   - predict:                 n
# label: Xóm trung tâm, xã Khánh Lợi, Huyện Yên Khánh, Ninh Bình                - predict:                 n
#
# Out of 365 samples:  Mean edit distance: 54.195 Mean normalized edit distance: 0.774
# Epoch 2/60
# 486/486 [==============================] - 565s 1s/step - loss: 189.0789 - val_loss: 187.6073
#
# Epoch 00002: val_loss improved from 193.82497 to 187.60734, saving model to model/best_0.h5
# label: Xóm Chiền A, Xã Nam Dương, Huyện Nam Trực, Nam Định                    - predict:               , Chí Minh
# label: 548-550 Điện Biên Phủ, Phường Thanh Khê Đông, Quận Thanh Khê, Đà Nẵng  - predict:              , , Chí Minh
# label: 1275/4 Phan Văn Trị, Phường 10, Quận Gò Vấp, TP Hồ Chí Minh            - predict:              , , Chí Minh
#
# Out of 365 samples:  Mean edit distance: 53.630 Mean normalized edit distance: 0.766
# Epoch 3/60
# 486/486 [==============================] - 562s 1s/step - loss: 181.8522 - val_loss: 171.6652
#
# Epoch 00003: val_loss improved from 187.60734 to 171.66516, saving model to model/best_0.h5
# label: Phường Quảng Thọ, Thị Xã Ba Đồn, Quảng Bình                            - predict: T         , H, Chí Minh
# label: 172A/29 Lạc Long Quân, Phường 10, Quận 11, TP Hồ Chí Minh              - predict: T         , H, Chí Minh
# label: A2- 14NC Khu đô thị Bàu Bàng, Xã Lai Uyên, Huyện Bàu Bàng, Bình Dương  - predict: T         , H, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 54.438 Mean normalized edit distance: 0.778
# Epoch 4/60
# 486/486 [==============================] - 562s 1s/step - loss: 164.4251 - val_loss: 159.8818
#
# Epoch 00004: val_loss improved from 171.66516 to 159.88183, saving model to model/best_0.h5
# label: Số 427/16, khu phố 1, Phường Tân Định, Thị Xã Bến Cát, Bình Dương      - predict: Số      , , Tu, Quận T T, Cà Ninh
# label: Số 552B Võ Thị Sáu, Phường Mỹ Xuyên, Thành phố Long Xuyên, An Giang    - predict: Số      , , Tu, Quận T T, Cà Ninh
# label: 155 đường Hai Bà Trưng, Phường 06, Quận 3, TP Hồ Chí Minh              - predict: Số      , , Tu, Quận T T, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 50.649 Mean normalized edit distance: 0.724
# Epoch 5/60
# 486/486 [==============================] - 559s 1s/step - loss: 160.7161 - val_loss: 165.1436
#
# Epoch 00005: val_loss did not improve from 159.88183
# label: Số 64 Hạ Long, Phường 2, Thành Phố Vũng Tàu, Bà Rịa - Vũng Tàu         - predict: Số  T T T, T, Huệ Huệ Tu TP, Cà Ninh
# label: 145 Nguyễn Đình Chính, Phường 11, Quận Phú Nhuận, TP Hồ Chí Minh       - predict: Số  T T T, T, Huệ Huệ Tu TP, Cà Ninh
# label: SN 96 Tô Vĩnh Diện, Phường Điện Biên, Thành phố Thanh Hoá, Thanh Hoá   - predict: Số  T T T, T, Huệ Huệ Tu TP, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 51.825 Mean normalized edit distance: 0.740
# Epoch 6/60
# 486/486 [==============================] - 558s 1s/step - loss: 159.1584 - val_loss: 159.4251
#
# Epoch 00006: val_loss improved from 159.88183 to 159.42511, saving model to model/best_0.h5
# label: Số 251A, Thị trấn Bần Yên Nhân, Huyện Mỹ Hào, Hưng Yên                 - predict: T  T T, T, T, T, Tu T T, Cà Minh
# label: Số 1 Quản Trọng Linh, Phường 7, Quận 8, TP Hồ Chí Minh                 - predict: T  T T, T, T, T, Tu T T, Cà Minh
# label: Số 194A, Khóm Tân Thuận, Phường An Hòa, Thành Phố Sa Đéc, Đồng Tháp    - predict: T  T T, T, T, T, Tu T T , Cà Minh
#
# Out of 365 samples:  Mean edit distance: 51.964 Mean normalized edit distance: 0.742
# Epoch 7/60
# 486/486 [==============================] - 557s 1s/step - loss: 159.5136 - val_loss: 155.6389
#
# Epoch 00007: val_loss improved from 159.42511 to 155.63892, saving model to model/best_0.h5
# label: Số 7 Tổ 1, P. Lương Khánh Thiện, Thành Phố Phủ Lý, Hà Nam              - predict: 1       ,  T T, Cà Ninh
# label: Số 172 đại lộ Tôn Đức Thắng, Xã An Đồng, Huyện An Dương, Hải Phòng     - predict: 1       ,  T T, Cà Ninh
# label: Số 72, xóm 6, thôn Giang Cao, xã Bát Tràng, Huyện Gia Lâm, Hà Nội      - predict: 1       ,  T T , Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 54.055 Mean normalized edit distance: 0.772
# Epoch 8/60
# 486/486 [==============================] - 557s 1s/step - loss: 154.9366 - val_loss: 157.3425
#
# Epoch 00008: val_loss did not improve from 155.63892
# label: 908 Tạ Quang Bửu, Phường 5, Quận 8, TP Hồ Chí Minh                     - predict: 2 1   , hưng , , H T T H, Cà Ninh
# label: Thôn Tây, Xã An Vĩnh, Huyện Lý Sơn, Quảng Ngãi                         - predict: 2 1   , hưng , , H T, T H, Cà Ninh
# label: Đường Lý Thường Kiệt, Thị trấn Mộc Hóa, Huyện Mộc Hoá, Long An         - predict: 2 1   , hưng , , H T T H, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 49.288 Mean normalized edit distance: 0.704
# Epoch 9/60
# 486/486 [==============================] - 558s 1s/step - loss: 154.8557 - val_loss: 154.5987
#
# Epoch 00009: val_loss improved from 155.63892 to 154.59869, saving model to model/best_0.h5
# label: 868 Đường Tạ Quang Bửu, Phường 5, Quận 8, TP Hồ Chí Minh               - predict: Số  T T, Thư, hưng Tu, Huyện T T , Cà Ninh
# label: 48/38 Nguyễn Háo Vĩnh, Phường Tân Quý, Quận Tân phú, TP Hồ Chí Minh    - predict: Số  T T, Thư, hưng Tu, Huyện T T , Cà Ninh
# label: Số 9, phố Yên Ninh, Phường Trúc Bạch, Quận Ba Đình, Hà Nội             - predict: Số  T T, Thư, hưng Tu, Huyện T T , Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 47.855 Mean normalized edit distance: 0.684
# Epoch 10/60
# 486/486 [==============================] - 557s 1s/step - loss: 154.7971 - val_loss: 153.0530
#
# Epoch 00010: val_loss improved from 154.59869 to 153.05296, saving model to model/best_0.h5
# label: Thị trấn Chư Sê, Huyện Chư Sê, Gia Lai                                 - predict: T      H, Quận T TP, Chí Minh
# label: Tổ dân phố Trung Bình, Phường Dương Nội, Quận Hà Đông, Hà Nội          - predict: T      H, Quận T TP, Chí Minh
# label: 299 Trương Vĩnh Ký, Phường Tân Thành, Quận Tân phú, TP Hồ Chí Minh     - predict: T      H, Quận T TP, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 51.737 Mean normalized edit distance: 0.739
# Epoch 11/60
# 486/486 [==============================] - 559s 1s/step - loss: 153.0476 - val_loss: 152.3399
#
# Epoch 00011: val_loss improved from 153.05296 to 152.33994, saving model to model/best_0.h5
# label: Số 21, Điện Biên Phủ, Phường Mỹ Phú, Thành phố Cao Lãnh, Đồng Tháp     - predict: T      T, Tu, Quận T TP , Hà Ninh
# label: Số 171 Mai Hắc Đế, Phường Lê Đại Hành, Quận Hai Bà Trưng, Hà Nội       - predict: T      T, Tu, Quận T TP , Hà Ninh
# label: Lô 49 đường Trần Cừ, Quận Thanh Khê, Đà Nẵng                           - predict: T      T, Tu, Quận T TP , Hà Ninh
#
# Out of 365 samples:  Mean edit distance: 50.504 Mean normalized edit distance: 0.721
# Epoch 12/60
# 486/486 [==============================] - 562s 1s/step - loss: 151.9929 - val_loss: 154.2967
#
# Epoch 00012: val_loss did not improve from 152.33994
# label: Số 171A, Đường Điện Biên, Phường Lê Lợi, Thành phố Hưng yên, Hưng Yên  - predict: ấp    ,  T, H, Quận  TP , Chí Minh
# label: thôn Phước Lợi, Xã Phước Đồng, Thành Phố Nha Trang, Khánh Hòa          - predict: ấp   ,   Tu, Huệ  TP , Chí Minh
# label: Thôn Agrồng, Xã A Tiêng, Huyện Tây Giang, Quảng Nam                    - predict: ấp      huyện  TP , Chí Minh
#
# Out of 365 samples:  Mean edit distance: 50.293 Mean normalized edit distance: 0.718
# Epoch 13/60
# 486/486 [==============================] - 556s 1s/step - loss: 151.3972 - val_loss: 150.7230
#
# Epoch 00013: val_loss improved from 152.33994 to 150.72296, saving model to model/best_0.h5
# label: UBND xã Cẩm Lộc, Huyện Cẩm Xuyên, Hà Tĩnh                              - predict: Số   , ,  T Tu, Quận T, TP , Chí Minh
# label: Số 199, phố Trung Kính, Phường Trung Hoà, Quận Cầu Giấy, Hà Nội        - predict: Số   , ,  T Tu, Quận T, TP , Chí Minh
# label: 1217 đường 30/4, Phường 11, Thành Phố Vũng Tàu, Bà Rịa - Vũng Tàu      - predict: Số   , ,  T Tu, Quận T, TP , Chí Minh
#
# Out of 365 samples:  Mean edit distance: 48.890 Mean normalized edit distance: 0.698
# Epoch 14/60
# 486/486 [==============================] - 559s 1s/step - loss: 150.2231 - val_loss: 150.4378
#
# Epoch 00014: val_loss improved from 150.72296 to 150.43780, saving model to model/best_0.h5
# label: Xóm Chiền A, Xã Nam Dương, Huyện Nam Trực, Nam Định                    - predict: Số      T H, Quận T, TP , Chí Minh
# label: 117A Bình Thới, Phường 11, Quận 11, TP Hồ Chí Minh                     - predict: Số      T H, Quận T, TP , Chí Minh
# label: Số 251A, Thị trấn Bần Yên Nhân, Huyện Mỹ Hào, Hưng Yên                 - predict: Số      T H, Quận T, TP , Chí Minh
#
# Out of 365 samples:  Mean edit distance: 49.701 Mean normalized edit distance: 0.710
# Epoch 15/60
# 486/486 [==============================] - 558s 1s/step - loss: 151.2979 - val_loss: 163.0423
#
# Epoch 00015: val_loss did not improve from 150.43780
# label: 44/18 Đề Pô, Phường Phước Tân, Thành phố Nha Trang, Khánh Hòa          - predict: T        T, T, Huệ  P, Chí Minh
# label: Tổ dân phố 2, Lạc ý, Phường Đồng Tâm, Thành phố Vĩnh Yên, Vĩnh Phúc    - predict: T        T, T, Huệ  P, Chí Minh
# label: Tổ 4, ấp Xóm Gò, Xã Long Phước, Huyện Long Thành, Đồng Nai             - predict: T    ,   T, T, Huệ  P, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 52.151 Mean normalized edit distance: 0.745
# Epoch 16/60
# 486/486 [==============================] - 559s 1s/step - loss: 156.7541 - val_loss: 156.6633
#
# Epoch 00016: val_loss did not improve from 150.43780
# label: Xóm 1 Đồng Nhân, Xã Đông La, Huyện Hoài Đức, Hà Nội                    - predict: Số    ,    Quận T TP , Cà Minh
# label: Thọ Đa, Xã Kim Nỗ, Huyện Đông Anh, Hà Nội                              - predict: Tố    ,    Quận T TP , Cà Minh
# label: 22 Linh Trung, Phường Linh Trung, Quận Thủ Đức, TP Hồ Chí Minh         - predict: Số    ,    Quận T TP , Cà Minh
#
# Out of 365 samples:  Mean edit distance: 50.707 Mean normalized edit distance: 0.724
# Epoch 17/60
# 486/486 [==============================] - 560s 1s/step - loss: 155.4111 - val_loss: 153.2937
#
# Epoch 00017: val_loss did not improve from 150.43780
# label: 103A đường 23/10, Phường Phương Sơn, Thành phố Nha Trang, Khánh Hòa    - predict: T  T    T T, Huyện T T , Hà Minh
# label: Ngõ 102 đường Trường Chinh, Phường Phương Mai, Quận Đống đa, Hà Nội    - predict: T  T    T T, Huyện T T , Hà Minh
# label: 9D Thái Nguyên, Phường Phước Tân, Thành phố Nha Trang, Khánh Hòa       - predict: T  T    T T, Huyện T T , Hà Minh
#
# Out of 365 samples:  Mean edit distance: 51.441 Mean normalized edit distance: 0.735
# Epoch 18/60
# 486/486 [==============================] - 558s 1s/step - loss: 153.8889 - val_loss: 153.5419
#
# Epoch 00018: val_loss did not improve from 150.43780
# label: Số 45/114 Vạn Kiếp, Phường Thượng Lý, Quận Hồng Bàng, Hải Phòng        - predict: 1  T ,  , , Quận  TP , Chí Nội
# label: 71/23 Gò Xoài, Phường Bình Hưng Hòa A, Quận Bình Tân, TP Hồ Chí Minh   - predict: 1  T ,  , , Quận  TP , Chí Nội
# label: Hùng Vương, ấp Cầu Đồn, TT Huỳnh Hữu Nghĩa, Huyện Mỹ Tú, Sóc Trăng     - predict: 1  T ,  , , Quận  TP , Chí Nội
#
# Out of 365 samples:  Mean edit distance: 51.016 Mean normalized edit distance: 0.729
# Epoch 19/60
# 486/486 [==============================] - 560s 1s/step - loss: 151.5524 - val_loss: 151.1486
#
# Epoch 00019: val_loss did not improve from 150.43780
# label: K760/26 Điện Biên phủ, Phường Thanh Khê Tây, Quận Thanh Khê, Đà Nẵng   - predict: Số   ,  hưng  T, Quận T TP , Cà Ninh
# label: Số 1/47 Phạm Hữu Điều, Phường Niệm Nghĩa, Quận Lê Chân, Hải Phòng      - predict: Số   ,  hưng  T, Quận T TP , Cà Ninh
# label: B26 Bồ Hỏa, Phường Hà Cầu, Quận Hà Đông, Hà Nội                        - predict: Số   ,  hưng  T, Quận T TP , Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 47.411 Mean normalized edit distance: 0.677
# Epoch 20/60
# 486/486 [==============================] - 560s 1s/step - loss: 150.8574 - val_loss: 153.8501
#
# Epoch 00020: val_loss did not improve from 150.43780
# label: Thôn Minh Tân, Xã Quang Minh, Huyện Gia Lộc, Hải Dương                 - predict: Số  T  Tường T, T, Quận T, TP , Chí Minh
# label: Ngõ 102 đường Trường Chinh, Phường Phương Mai, Quận Đống đa, Hà Nội    - predict: Số  T , Tường T T, Quận T, TP , Chí Minh
# label: ấp 5, xã Nhị Thành, Huyện Thủ Thừa, Long An                            - predict: Số  T , Tường T T, Quận T, TP , Chí Minh
#
# Out of 365 samples:  Mean edit distance: 47.211 Mean normalized edit distance: 0.674
# Epoch 21/60
# 486/486 [==============================] - 559s 1s/step - loss: 149.5527 - val_loss: 149.5282
#
# Epoch 00021: val_loss improved from 150.43780 to 149.52825, saving model to model/best_0.h5
# label: Tổ 11A, ấp Đông Thành, Tân Đông Hiệp, Tx Dĩ An, Bình Dương             - predict: Số   , ,   T, Quận T TP , Cà Ninh
# label: Thôn Kim Giao, Xã Phổ Thuận, Huyện Đức Phổ, Quảng Ngãi                 - predict: Số   , ,   T, Quận T TP , Cà Ninh
# label: Thôn Thượng Giang, Xã Tây Giang, Huyện Tây Sơn, Bình Định              - predict: Số   , ,   T, Quận T TP , Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 49.611 Mean normalized edit distance: 0.709
# Epoch 22/60
# 486/486 [==============================] - 561s 1s/step - loss: 148.5506 - val_loss: 149.6760
#
# Epoch 00022: val_loss did not improve from 149.52825
# label: 487A/8 KV Bình Yên A, P Long Hòa, Quận Bình Thuỷ, Cần Thơ              - predict: Số   ,  X T Tà, Huyện T T , Cà Nội
# label: 382/12/24 Tân Kỳ Tân Quý, Phường Sơn Kỳ, Quận Tân phú, TP Hồ Chí Minh  - predict: Số   ,  X T Tà, Huyện T T , Cà Nội
# label: Thôn Hòa Sơn, Xã Cao Thượng, Huyện Tân Yên, Bắc Giang                  - predict: Số   ,  X T Tà, Huyện T T , Cà Nội
#
# Out of 365 samples:  Mean edit distance: 51.085 Mean normalized edit distance: 0.730
# Epoch 23/60
# 486/486 [==============================] - 559s 1s/step - loss: 148.0684 - val_loss: 147.9799
#
# Epoch 00023: val_loss improved from 149.52825 to 147.97993, saving model to model/best_0.h5
# label: 893/12/22 Hoàng Sa, Phường 09, Quận 3, TP Hồ Chí Minh                  - predict: T   ,   T, Quận T T , Chí Nội
# label: Số 256, tổ 41, Phường Hoàng Văn Thụ, Quận Hoàng Mai, Hà Nội            - predict: T   ,   T, Quận T T , Chí Nội
# label: 479 Khu phố 5, Phường 9, Thành phố Mỹ Tho, Tiền Giang                  - predict: T   ,   T, Quận T T , Chí Nội
#
# Out of 365 samples:  Mean edit distance: 51.419 Mean normalized edit distance: 0.735
# Epoch 24/60
# 486/486 [==============================] - 559s 1s/step - loss: 147.3917 - val_loss: 147.1516
#
# Epoch 00024: val_loss improved from 147.97993 to 147.15164, saving model to model/best_0.h5
# label: Số 298, Nguyễn Trãi, Phường Tân Sơn, Thành phố Thanh Hoá, Thanh Hoá    - predict: Số   ,  hưng , T, Quận B TP H, Chí Ninh
# label: 182 Phan Văn Hân P.17, Phường 17, Quận Bình Thạnh, TP Hồ Chí Minh      - predict: Số   ,  hưng , T, Quận B TP H, Chí Ninh
# label: Số 2C Vạn Phúc, Phường Ngọc Khánh, Quận Ba Đình, Hà Nội                - predict: Số   ,  hưng , T, Quận B TP H, Chí Ninh
#
# Out of 365 samples:  Mean edit distance: 46.734 Mean normalized edit distance: 0.668
# Epoch 25/60
# 486/486 [==============================] - 558s 1s/step - loss: 146.8771 - val_loss: 147.4870
#
# Epoch 00025: val_loss did not improve from 147.15164
# label: Số 156 Xã Đàn 2, Phường Nam Đồng, Quận Đống Đa, Hà Nội                 - predict: T  T ,  hưng  hành Huyện T TP H, Chí Minh
# label: Khóm Minh Thuận B, TTCN, Huyện Cầu Ngang, Trà Vinh                     - predict: T  T ,  hưng  hành Huyện T TP H, Chí Minh
# label: Số 402, ấp 3, Xã Vị Thanh, Huyện Vị Thủy, Hậu Giang                    - predict: T  T ,  hưng  hành Huyện T TP H, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 47.619 Mean normalized edit distance: 0.680
# Epoch 26/60
# 486/486 [==============================] - 558s 1s/step - loss: 146.5724 - val_loss: 147.2538
#
# Epoch 00026: val_loss did not improve from 147.15164
# label: Thị trấn Thanh Nê, Huyện Kiến Xương, Thái Bình                         - predict: Số  T ,  hưng T, Tà, Quận T TP H, Chí Minh
# label: Số 61A, Thị trấn Yên Mỹ, Huyện Yên Mỹ, Hưng Yên                        - predict: Số  T ,  hưng T, Tà, Quận T TP H, Chí Minh
# label: Khu 18, Xã Phú Hộ, Thị xã Phú Thọ, Phú Thọ                             - predict: Số  T ,  hưng T, Tà, Quận T TP H, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 46.504 Mean normalized edit distance: 0.664
# Epoch 27/60
# 486/486 [==============================] - 558s 1s/step - loss: 146.3913 - val_loss: 147.4656
#
# Epoch 00027: val_loss did not improve from 147.15164
# label: ấp Hòa Đông, Xã Đông Hòa, Huyện An Minh, Kiên Giang                    - predict: T   , hưng  T, Quận T TP H, Chí Minh
# label: Tổ dân phố Trung Bình, Phường Dương Nội, Quận Hà Đông, Hà Nội          - predict: T   , hưng  T, Quận T TP H, Chí Minh
# label: Số 6A, phố Trần Quốc Toản, phường Hàng Bài, Quận Hoàn Kiếm, Hà Nội     - predict: T   , hưng  T, Quận T TP H, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 47.203 Mean normalized edit distance: 0.674
# Epoch 28/60
# 486/486 [==============================] - 559s 1s/step - loss: 145.9140 - val_loss: 148.4843
#
# Epoch 00028: val_loss did not improve from 147.15164
# label: SN 24 ấp Hòa Bình, Xã Túc Trưng, Huyện Định Quán, Đồng Nai             - predict: Số   T , , hưng  Tà, Quận Tà TP H, Cà Minh
# label: Số 251A, Thị trấn Bần Yên Nhân, Huyện Mỹ Hào, Hưng Yên                 - predict: Số   T , , hưng  Tà, Quận Tà TP H, Cà Minh
# label: Số 41, đường Tô Hiệu, TP. Sơn La, Sơn La                               - predict: Số   T , , hưng  Tà, Quận T TP H, Cà Minh
#
# Out of 365 samples:  Mean edit distance: 46.255 Mean normalized edit distance: 0.661
# Epoch 29/60
# 486/486 [==============================] - 558s 1s/step - loss: 145.7028 - val_loss: 145.8891
#
# Epoch 00029: val_loss improved from 147.15164 to 145.88910, saving model to model/best_0.h5
# label: Bản Mo Nghè 3, Xã Quang Huy, Huyện Phù Yên, Sơn La                     - predict: Số    , hưng , Tà, Quận T TP H, Cà Ninh
# label: 563 Núi Thành, Phường Hoà Cường Nam, Quận Hải Châu, Đà Nẵng            - predict: Số    , hưng , Tà, Quận T TP H, Cà Ninh
# label: Tòa nhà H2, 196 Hoàng Diệu, phường 08, Quận 4, TP Hồ Chí Minh          - predict: Số    , hưng , Tà, Quận T TP H, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 47.151 Mean normalized edit distance: 0.674
# Epoch 30/60
# 486/486 [==============================] - 557s 1s/step - loss: 145.3232 - val_loss: 145.0162
#
# Epoch 00030: val_loss improved from 145.88910 to 145.01616, saving model to model/best_0.h5
# label: Số 9, phố Yên Ninh, Phường Trúc Bạch, Quận Ba Đình, Hà Nội             - predict: Số    , hưng  Tà, Quận T TP H, Chí Minh
# label: Thôn Gia Lâm, Xã Lệ Chi, Huyện Gia Lâm, Hà Nội                         - predict: Số    , hưng  Tà, Quận T TP H, Chí Minh
# label: Tổ 8, ấp Thạnh Phú, Xã Khánh An, Huyện An Phú, An Giang                - predict: Số    , hưng  Tà, Quận T TP H, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 46.693 Mean normalized edit distance: 0.667
# Epoch 31/60
# 486/486 [==============================] - 558s 1s/step - loss: 145.2870 - val_loss: 146.7045
#
# Epoch 00031: val_loss did not improve from 145.01616
# label: Phường Quảng Thọ, Thị Xã Ba Đồn, Quảng Bình                            - predict: Số    , hưng , Tà, Quận T TP H, Chí Minh
# label: Xóm 6, Xã Ngũ Lão, Huyện Thuỷ Nguyên, Hải Phòng                        - predict: Số    , hưng , Tà, Quận T TP H, Chí Minh
# label: 61/21 Lý Tự Trọng, Quận Ninh Kiều, Cần Thơ                             - predict: Số    , hưng , Tà, Quận T TP H, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 46.718 Mean normalized edit distance: 0.667
# Epoch 32/60
# 486/486 [==============================] - 556s 1s/step - loss: 145.0150 - val_loss: 145.7460
#
# Epoch 00032: val_loss did not improve from 145.01616
# label: Tổ 8, Thị trấn Điện Biên Đông, Huyện Điện Biên Đông, Điện Biên         - predict: Tố    , hưng  Tà, Huyện T TP H, Cà Minh
# label: Lô D5H CN KCN Mỹ Phước 3, Thị Xã Bến Cát, Bình Dương                   - predict: Tố    , hưng  Tà, Huyện T TP H, Cà Minh
# label: Số nhà 53, Ngõ 96 Phố Đại Từ, Phường Đại Kim, Quận Hoàng Mai, Hà Nội   - predict: Tố    , hưng  Tà, Huyện T TP H, Cà Minh
#
# Out of 365 samples:  Mean edit distance: 47.482 Mean normalized edit distance: 0.678
# Epoch 33/60
# 486/486 [==============================] - 553s 1s/step - loss: 144.8023 - val_loss: 145.8482
#
# Epoch 00033: val_loss did not improve from 145.01616
# label: Số 21, Điện Biên Phủ, Phường Mỹ Phú, Thành phố Cao Lãnh, Đồng Tháp     - predict: Số  T , , hưng  Tà, Quận T TP H, Cà Minh
# label: 40 Bà Huyện Thanh Quan, Quận 3, TP Hồ Chí Minh                         - predict: Số  T , , hưng  Tà, Quận T TP H, Cà Minh
# label: Thôn Gia Lâm, Xã Lệ Chi, Huyện Gia Lâm, Hà Nội                         - predict: Số  T , , hưng  Tà, Quận T TP H, Cà Minh
#
# Out of 365 samples:  Mean edit distance: 46.759 Mean normalized edit distance: 0.668
# Epoch 34/60
# 486/486 [==============================] - 540s 1s/step - loss: 144.5872 - val_loss: 146.2574
#
# Epoch 00034: val_loss did not improve from 145.01616
# label: 155 đường Hai Bà Trưng, Phường 06, Quận 3, TP Hồ Chí Minh              - predict: T  T , , Xã T Tà, Huyện T TP H, Cà Minh
# label: 93/9 Lũy Bán Bích, Phường Tân Thới Hoà, Quận Tân phú, TP Hồ Chí Minh   - predict: T  T , , Xã T Tà, Huyện T TP H, Cà Minh
# label: 382/12/24 Tân Kỳ Tân Quý, Phường Sơn Kỳ, Quận Tân phú, TP Hồ Chí Minh  - predict: T  T , , Xã T Tà, Huyện T TP H, Cà Minh
#
# Out of 365 samples:  Mean edit distance: 49.290 Mean normalized edit distance: 0.704
# Epoch 35/60
# 486/486 [==============================] - 538s 1s/step - loss: 144.6745 - val_loss: 145.2792
#
# Epoch 00035: val_loss did not improve from 145.01616
# label: Số 171 Mai Hắc Đế, Phường Lê Đại Hành, Quận Hai Bà Trưng, Hà Nội       - predict: Số    , hưng  Tà, Huyện T TP H, Cà Ninh
# label: Đường Lý Thường Kiệt, Thị trấn Mộc Hóa, Huyện Mộc Hoá, Long An         - predict: Số    , hưng  Tà, Huyện T TP H, Cà Ninh
# label: Tòa nhà H2, 196 Hoàng Diệu, phường 08, Quận 4, TP Hồ Chí Minh          - predict: Số    , hưng  Tà, Huyện T TP H, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 47.893 Mean normalized edit distance: 0.684
# Epoch 36/60
# 486/486 [==============================] - 529s 1s/step - loss: 144.4403 - val_loss: 142.4513
#
# Epoch 00036: val_loss improved from 145.01616 to 142.45130, saving model to model/best_0.h5
# label: Số 176 đường Thanh Niên, Phường Hồng Hà, Thành Phố Yên Bái, Yên Bái    - predict: Số    , Phường , Tà, Huyện T TP H, Cà Ninh
# label: Cự Môn, Xã Thạch Đồng, Huyện Thạch Thành, Thanh Hoá                    - predict: Số    , Phường , Tà, Quận T TP H, Cà Ninh
# label: 479 Khu phố 5, Phường 9, Thành phố Mỹ Tho, Tiền Giang                  - predict: Số    , Phường , Tà, Quận T TP H, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 46.058 Mean normalized edit distance: 0.658
# Epoch 37/60
# 486/486 [==============================] - 526s 1s/step - loss: 144.2568 - val_loss: 145.8057
#
# Epoch 00037: val_loss did not improve from 142.45130
# label: 458/10/11 Huỳnh Tấn Phát, Phường Bình Thuận, Quận 7, TP Hồ Chí Minh    - predict: Số    , hưng  Tà, Huyện T TP H, Cà Ninh
# label: 23-23A Trần Khắc Chân, Phường Tân Định, Quận 1, TP Hồ Chí Minh         - predict: Số    , hưng  Tà, Huyện T TP H, Cà Ninh
# label: Số 1/47 Phạm Hữu Điều, Phường Niệm Nghĩa, Quận Lê Chân, Hải Phòng      - predict: Số    , hưng  Tà, Huyện T TP H, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 47.800 Mean normalized edit distance: 0.683
# Epoch 38/60
# 486/486 [==============================] - 538s 1s/step - loss: 144.0914 - val_loss: 146.8978
#
# Epoch 00038: val_loss did not improve from 142.45130
# label: 18A Bàu Cát 8, Phường 10, Quận Tân Bình, TP Hồ Chí Minh                - predict: T    , hưng , Tà, Huyện T TP H, Cà Nội
# label: 66 An Hội, Phường 13, Quận Gò Vấp, TP Hồ Chí Minh                      - predict: T    , hưng , Tà, Huyện T TP H, Cà Nội
# label: Tảo Dương Văn, Huyện Ứng Hoà, Hà Nội                                   - predict: T    , hưng , Tà, Huyện T TP H, Cà Nội
#
# Out of 365 samples:  Mean edit distance: 48.658 Mean normalized edit distance: 0.695
# Epoch 39/60
# 486/486 [==============================] - 549s 1s/step - loss: 144.0144 - val_loss: 144.1080
#
# Epoch 00039: val_loss did not improve from 142.45130
# label: Xã Kiệt Sơn, Huyện Tân Sơn, Phú Thọ                                    - predict: T    , hưng T, Tà, Huyện T TP H, Cà Ninh
# label: 139 Hoàng Hữu Nam, Phường Tân Phú, Quận 9, TP Hồ Chí Minh              - predict: T    , hưng T, Tà, Huyện T TP H, Cà Ninh
# label: 893/12/22 Hoàng Sa, Phường 09, Quận 3, TP Hồ Chí Minh                  - predict: T    , hưng T, Tà, Huyện T TP H, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 47.852 Mean normalized edit distance: 0.684
# Epoch 40/60
# 486/486 [==============================] - 533s 1s/step - loss: 143.7532 - val_loss: 143.0035
#
# Epoch 00040: val_loss did not improve from 142.45130
# label: Số 56 đường Hai Bà Trưng, Phường 6, Thành phố Đà Lạt, Lâm Đồng         - predict: T   , Phường  Tà, Quận T TP H, Cà Ninh
# label: Phường Quảng Thọ, Thị Xã Ba Đồn, Quảng Bình                            - predict: T   , Phường  Tà, Quận T TP H, Cà Ninh
# label: Km 46, quốc lộ 5, Thị trấn Lai Cách, Huyện Cẩm Giàng, Hải Dương        - predict: T   , Phường  Tà, Quận T TP H, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 46.767 Mean normalized edit distance: 0.668
# Epoch 41/60
# 486/486 [==============================] - 545s 1s/step - loss: 143.7974 - val_loss: 144.5208
#
# Epoch 00041: val_loss did not improve from 142.45130
# label: Tổ dân phố Tân Phong, Thị xã Kỳ Anh, Hà Tĩnh                           - predict: T    , Phường  Tà, Huyện T TP H, Cà Minh
# label: 899/9A Bình Giã, Phường 10, Thành Phố Vũng Tàu, Bà Rịa - Vũng Tàu      - predict: T    , Phường  Tà, Huyện T TP H, Cà Minh
# label: Thôn Tây, Xã An Vĩnh, Huyện Lý Sơn, Quảng Ngãi                         - predict: T    , Phường  Tà, Huyện T TP H, Cà Minh
#
# Out of 365 samples:  Mean edit distance: 46.800 Mean normalized edit distance: 0.669
# Epoch 42/60
# 486/486 [==============================] - 555s 1s/step - loss: 143.6414 - val_loss: 145.9175
#
# Epoch 00042: val_loss did not improve from 142.45130
# label: Xã Quảng Hùng, Huyện Quảng Xương, Thanh Hoá                            - predict: Số    , Phường  Tà, Huyện T TP H, Hà Ninh
# label: 491 Trần Phú, Thành phố Bảo Lộc, Lâm Đồng                              - predict: Số    , Phường  Tà, Huyện T TP H, Hà Ninh
# label: 131 Đinh Tiên Hoàng, Phường 3, Quận Bình Thạnh, TP Hồ Chí Minh         - predict: Số    , Phường  Tà, Huyện T TP H, Hà Ninh
#
# Out of 365 samples:  Mean edit distance: 46.745 Mean normalized edit distance: 0.668
# Epoch 43/60
# 486/486 [==============================] - 553s 1s/step - loss: 143.5689 - val_loss: 144.3770
#
# Epoch 00043: val_loss did not improve from 142.45130
# label: Xóm Minh Nghĩa, Xã Đồng Thái, Huyện Ba Vì, Hà Nội                      - predict: Số   T , Phường  Tà, Huyện B TP H, Cà Ninh
# label: Số 632 Tổ 4, Thạnh Trung, Thạnh Tây, Huyện Tân Biên, Tây Ninh          - predict: Số   T , Phường  Tà, Huyện B TP H, Cà Ninh
# label: Nguyễn Quyền, Phường Võ Cường, Thành phố Bắc Ninh, Bắc Ninh            - predict: Số   T , Phường  Tà, Huyện B TP H, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 46.444 Mean normalized edit distance: 0.663
# Epoch 44/60
# 486/486 [==============================] - 556s 1s/step - loss: 143.4155 - val_loss: 145.7767
#
# Epoch 00044: val_loss did not improve from 142.45130
# label: 117 Nguyễn Trãi, Phường 02, Quận 5, TP Hồ Chí Minh                     - predict: T   , Phường  Tà, Quận T TP H, Chí Ninh
# label: 466/4 Lê Quang Định, Phường 11, Quận Bình Thạnh, TP Hồ Chí Minh        - predict: T   , Phường  Tà, Huyện T TP H, Chí Ninh
# label: Thị trấn Chư Sê, Huyện Chư Sê, Gia Lai                                 - predict: T   , Phường  Tà, Huyện T TP H, Chí Ninh
#
# Out of 365 samples:  Mean edit distance: 47.068 Mean normalized edit distance: 0.672
# Epoch 45/60
# 486/486 [==============================] - 554s 1s/step - loss: 143.3850 - val_loss: 142.7792
#
# Epoch 00045: val_loss did not improve from 142.45130
# label: Số 64 Tổ 3, ấp 14, Xã Long Trung, Huyện Cai Lậy, Tiền Giang            - predict: Số    , Phường  Tà, Huyện B TP H, Cà Ninh
# label: 180 Đường số 3, Phường 9, Quận Gò Vấp, TP Hồ Chí Minh                  - predict: Số    , Phường  Tà, Huyện B TP H, Cà Ninh
# label: 59 Đường số 9, Cư xá Đài Ra Đa, Phường 13, Quận 6, TP Hồ Chí Minh      - predict: Số    , Phường  Tà, Huyện B TP H, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 46.584 Mean normalized edit distance: 0.665
# Epoch 46/60
# 486/486 [==============================] - 557s 1s/step - loss: 143.2907 - val_loss: 141.6135
#
# Epoch 00046: val_loss improved from 142.45130 to 141.61350, saving model to model/best_0.h5
# label: Chợ Lý Hoà, Xã Hải Trạch, Huyện Bố Trạch, Quảng Bình                   - predict: T    , Phường  Quận, Quận T TP H, Hà Ninh
# label: Số 1/47 Phạm Hữu Điều, Phường Niệm Nghĩa, Quận Lê Chân, Hải Phòng      - predict: T    , Phường  Quận, Quận H TP H, Hà Ninh
# label: 286 Trần Hưng đạo, TT Bồng Sơn, Huyện Hoài Nhơn, Bình Định             - predict: T    , Phường  Quận, Quận H TP H, Hà Ninh
#
# Out of 365 samples:  Mean edit distance: 46.942 Mean normalized edit distance: 0.671
# Epoch 47/60
# 486/486 [==============================] - 559s 1s/step - loss: 143.2772 - val_loss: 145.3798
#
# Epoch 00047: val_loss did not improve from 141.61350
# label: Ngõ 102 đường Trường Chinh, Phường Phương Mai, Quận Đống đa, Hà Nội    - predict: T   , hưng  Tà, Huyện B T H, Cà Ninh
# label: Số 9, phố Yên Ninh, Phường Trúc Bạch, Quận Ba Đình, Hà Nội             - predict: T   , hưng  Tà, Huyện B T H, Cà Ninh
# label: 121 Lê Niệm, Phường Phú Thạnh, Quận Tân phú, TP Hồ Chí Minh            - predict: T   , hưng  Tà, Huyện B T H, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 48.578 Mean normalized edit distance: 0.694
# Epoch 48/60
# 486/486 [==============================] - 556s 1s/step - loss: 143.2277 - val_loss: 144.4896
#
# Epoch 00048: val_loss did not improve from 141.61350
# label: Tổ dân phố Tân Phong, Thị xã Kỳ Anh, Hà Tĩnh                           - predict: Số    , Phường  Tà, Huyện B TP H, Cà Minh
# label: Tổ 4, Phường Trần Phú, TP Hà Giang, Hà Giang                           - predict: Số    , Phường  Tà, Huyện B TP H, Cà Minh
# label: 101 Hùng Vương, Phường An Phú, Thành Phố Tam Kỳ, Quảng Nam             - predict: Số    , Phường  Tà, Huyện B TP H, Cà Minh
#
# Out of 365 samples:  Mean edit distance: 46.814 Mean normalized edit distance: 0.669
# Epoch 49/60
# 486/486 [==============================] - 556s 1s/step - loss: 143.1502 - val_loss: 141.5522
#
# Epoch 00049: val_loss improved from 141.61350 to 141.55216, saving model to model/best_0.h5
# label: Số 251A, Thị trấn Bần Yên Nhân, Huyện Mỹ Hào, Hưng Yên                 - predict: T    , Phường  Tà, Huyện T TP H, Cà Ninh
# label: Km 46, quốc lộ 5, Thị trấn Lai Cách, Huyện Cẩm Giàng, Hải Dương        - predict: T    , Phường  Tà, Huyện T TP H, Cà Ninh
# label: Hùng Vương, ấp Cầu Đồn, TT Huỳnh Hữu Nghĩa, Huyện Mỹ Tú, Sóc Trăng     - predict: T    , Phường  Tà, Huyện T TP H, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 46.975 Mean normalized edit distance: 0.671
# Epoch 50/60
# 486/486 [==============================] - 556s 1s/step - loss: 142.9648 - val_loss: 143.4081
#
# Epoch 00050: val_loss did not improve from 141.55216
# label: 1275/4 Phan Văn Trị, Phường 10, Quận Gò Vấp, TP Hồ Chí Minh            - predict: T   , hưng Tà, Huyện T T H, Hà Ninh
# label: Số 13C, Khu dân cư Nam Phương, Phường An Phú, Tx Thuận An, Bình Dương  - predict: T   , hưng Tà, Huyện T T H, Hà Ninh
# label: 27A Hoàng Việt, Phường 4, Quận Tân Bình, TP Hồ Chí Minh                - predict: T   , hưng Tà, Huyện T T H, Hà Ninh
#
# Out of 365 samples:  Mean edit distance: 48.748 Mean normalized edit distance: 0.696
# Epoch 51/60
# 486/486 [==============================] - 556s 1s/step - loss: 143.0416 - val_loss: 142.1609
#
# Epoch 00051: val_loss did not improve from 141.55216
# label: KP F6/15 ấp 6B, Xã Vĩnh Lộc A, Huyện Bình Chánh, TP Hồ Chí Minh        - predict: 1    , Phường  Tà, Quận H TP H, Cà Minh
# label: 893/12/22 Hoàng Sa, Phường 09, Quận 3, TP Hồ Chí Minh                  - predict: 1    , Phường  Tà, Quận H TP H, Cà Minh
# label: Thôn Non, Xã Thanh Lưu, Huyện Thanh Liêm, Hà Nam                       - predict: 1    , Phường  Tà, Quận H TP H, Cà Minh
#
# Out of 365 samples:  Mean edit distance: 46.808 Mean normalized edit distance: 0.669
# Epoch 52/60
# 486/486 [==============================] - 555s 1s/step - loss: 142.9714 - val_loss: 142.9098
#
# Epoch 00052: val_loss did not improve from 141.55216
# label: Số 2C Vạn Phúc, Phường Ngọc Khánh, Quận Ba Đình, Hà Nội                - predict: Số    , Phường  Tà, Huyện T TP , Cà Ninh
# label: Số 5 ngõ 196 phố Thái Thịnh, Phường Láng Hạ, Quận Đống Đa, Hà Nội      - predict: Số    , Phường  Tà, Huyện Đan TP , Cà Ninh
# label: Bản Mo Nghè 3, Xã Quang Huy, Huyện Phù Yên, Sơn La                     - predict: Số    , Phường  Tà, Huyện Đan TP , Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 46.915 Mean normalized edit distance: 0.670
# Epoch 53/60
# 486/486 [==============================] - 558s 1s/step - loss: 142.9210 - val_loss: 145.8174
#
# Epoch 00053: val_loss did not improve from 141.55216
# label: Số 398 Đường Cách Mạng Tháng Tám, Phường 11, Quận 3, TP Hồ Chí Minh    - predict: T    , Phường  Tà, Huyện Đan TP H, Cà Ninh
# label: 5/121/1 Nơ Trang Long, Phường 7, Quận Bình Thạnh, TP Hồ Chí Minh       - predict: T    , Phường  Tà, Huyện Đan TP H, Cà Ninh
# label: Phường Mai Dịch, Quận Cầu Giấy, Hà Nội                                 - predict: T    , Phường  Tà, Huyện Đan TP H, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 46.948 Mean normalized edit distance: 0.671
# Epoch 54/60
# 486/486 [==============================] - 560s 1s/step - loss: 142.7658 - val_loss: 141.7263
#
# Epoch 00054: val_loss did not improve from 141.55216
# label: 27 Bàu Tràm 2, Phường Khuê Trung, Quận Cẩm Lệ, Đà Nẵng                 - predict: Số   T , Phường  Tà, Quận T TP H, Chí Nội
# label: 487A/8 KV Bình Yên A, P Long Hòa, Quận Bình Thuỷ, Cần Thơ              - predict: Số   T , Phường  Tà, Quận T TP H, Chí Nội
# label: 121 Lê Niệm, Phường Phú Thạnh, Quận Tân phú, TP Hồ Chí Minh            - predict: Số   T , Phường  Tà, Quận T TP H, Chí Nội
#
# Out of 365 samples:  Mean edit distance: 46.255 Mean normalized edit distance: 0.661
# Epoch 55/60
# 486/486 [==============================] - 558s 1s/step - loss: 142.6043 - val_loss: 144.4791
#
# Epoch 00055: val_loss did not improve from 141.55216
# label: Phường Mai Dịch, Quận Cầu Giấy, Hà Nội                                 - predict: T   , Phường  Tà, Huyện B TP H, Cà Minh
# label: Số 19, ngõ 100, phố Sài Đồng, Phường Sài Đồng, Quận Long Biên, Hà Nội  - predict: T   , Phường  Tà, Huyện B TP H, Cà Minh
# label: Thôn Cao Thắng, Xã Kỳ Xuân, Huyện Kỳ Anh, Hà Tĩnh                      - predict: T   , Phường  Tà, Huyện B TP H, Cà Minh
#
# Out of 365 samples:  Mean edit distance: 47.345 Mean normalized edit distance: 0.676
# Epoch 56/60
# 486/486 [==============================] - 562s 1s/step - loss: 142.7115 - val_loss: 142.7787
#
# Epoch 00056: val_loss did not improve from 141.55216
# label: Xóm Chiền A, Xã Nam Dương, Huyện Nam Trực, Nam Định                    - predict: T    , hưng , Tà, Huyện T TP H, Cà Ninh
# label: 116/13 Tuyên Quang, Phường Phú Thủy, Thành Phố Phan Thiết, Bình Thuận  - predict: T    , hưng , Tà, Huyện T TP H, Cà Ninh
# label: 172A/29 Lạc Long Quân, Phường 10, Quận 11, TP Hồ Chí Minh              - predict: T    , hưng , Tà, Huyện T TP H, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 47.838 Mean normalized edit distance: 0.683
# Epoch 57/60
# 486/486 [==============================] - 565s 1s/step - loss: 142.7529 - val_loss: 143.8223
#
# Epoch 00057: val_loss did not improve from 141.55216
# label: Số 19/5, ngõ 178 Tây Sơn, Phường Trung Liệt, Quận Đống đa, Hà Nội      - predict: Số    , Phường  Tà, Huyện B TP H, Cà Ninh
# label: Số 02 đường Trần Hưng Đạo, Phường 3, Thành Phố Đà Lạt, Lâm Đồng        - predict: Số    , Phường  Tà, Huyện B TP H, Cà Ninh
# label: 558 âu Cơ, Phường 10, Quận Tân Bình, TP Hồ Chí Minh                    - predict: Số    , Phường  Tà, Huyện B TP H, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 46.751 Mean normalized edit distance: 0.668
# Epoch 58/60
# 486/486 [==============================] - 567s 1s/step - loss: 142.6031 - val_loss: 142.8522
#
# Epoch 00058: val_loss did not improve from 141.55216
# label: Phường Mai Dịch, Quận Cầu Giấy, Hà Nội                                 - predict: Số    , Phường  Tà, Quận H TP H, Cà Ninh
# label: Lô 49 đường Trần Cừ, Quận Thanh Khê, Đà Nẵng                           - predict: Số    , Phường  Tà, Quận H TP H, Cà Ninh
# label: Thôn Hồng Kỳ, Xã Sơn Phú, Huyện Hương Sơn, Hà Tĩnh                     - predict: Số    , Phường  Tà, Quận H TP H, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 45.885 Mean normalized edit distance: 0.655
# Epoch 59/60
# 486/486 [==============================] - 569s 1s/step - loss: 142.5075 - val_loss: 141.9560
#
# Epoch 00059: val_loss did not improve from 141.55216
# label: 036 Lô 9 Cư Xá Thanh Đa, Phường 27, Quận Bình Thạnh, TP Hồ Chí Minh    - predict: Số    , Phường  Tà, Quận T TP H, Chí Minh
# label: 3/27A QL22, Huyện Hóc Môn, TP Hồ Chí Minh                              - predict: Số    , Phường  Tà, Quận T TP H, Chí Minh
# label: 819/30 Nguyễn Kiệm, Phường 3, Quận Gò Vấp, TP Hồ Chí Minh              - predict: Số    , Phường  Tà, Quận T TP H, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 45.485 Mean normalized edit distance: 0.650

# %%
idx = 1
train_kfold(idx, kfold, datapath, labelpath, epochs, batch_size, lr, finetune, name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a4ec1c6c20c8> in <module>()
#       1 idx = 1
# ----> 2 train_kfold(idx, kfold, datapath, labelpath, epochs, batch_size, lr, finetune, name)
#
# NameError: name 'train_kfold' is not defined

# %%
idx = 2
train_kfold(idx, kfold, datapath, labelpath, epochs, batch_size, lr, finetune, name)

# %%
idx = 3
train_kfold(idx, kfold, datapath, labelpath, epochs, batch_size, lr, finetune, name)

# %%
idx = 4
train_kfold(idx, kfold, datapath, labelpath, epochs, batch_size, lr, finetune, name)

# %%
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 5s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4249: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4229: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# the_inputs (InputLayer)         (None, 1280, 64, 3)  0
# __________________________________________________________________________________________________
# vgg16 (Sequential)              multiple             14714688    the_inputs[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 80, 2048)     0           vgg16[1][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 80, 512)      1049088     reshape[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 80, 512)      0           dense1[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 512, 80)      0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512, 80)      6480        permute_1[0][0]
# __________________________________________________________________________________________________
# dim_reduction (Lambda)          (None, 80)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (None, 512, 80)      0           dim_reduction[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 80, 512)      0           repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# attention_mul (Multiply)        (None, 80, 512)      0           dropout_1[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 80, 512)      1574912     attention_mul[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 80, 512)      1574912     bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 80, 151)      77463       bidirectional_2[0][0]
# __________________________________________________________________________________________________
# the_labels (InputLayer)         (None, 70)           0
# __________________________________________________________________________________________________
# input_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# label_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           dense2[0][0]
#                                                                  the_labels[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 18,997,543
# Trainable params: 18,997,543
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 1458  Image Loading start...  data/Address/
# Image Loading finish...
# 365  Image Loading start...  data/Address/
# Image Loading finish...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1/60
# 486/486 [==============================] - 558s 1s/step - loss: 200.1970 - val_loss: 196.5751
#
# Epoch 00001: val_loss improved from inf to 196.57513, saving model to model/best_0.h5
# label: Số 6 Vũ Ngọc Phan, Phường Láng Hạ, Quận Đống đa, Hà Nội                - predict:               Nh
# label: Thôn Hữu Tân, Xã Tân Ninh, Huyện Quảng Ninh, Quảng Bình                - predict:               Nh
# label: Số 51 Triều Khúc, Phường Thanh Xuân Bắc, Quận Thanh Xuân, Hà Nội       - predict:               Nh
#
# Out of 365 samples:  Mean edit distance: 55.992 Mean normalized edit distance: 0.800
# Epoch 2/60
# 486/486 [==============================] - 547s 1s/step - loss: 187.8792 - val_loss: 181.6689
#
# Epoch 00002: val_loss improved from 196.57513 to 181.66886, saving model to model/best_0.h5
# label: Số 7, ngõ 1/178 phố Thái Hà, Phường Trung Liệt, Quận Đống đa, Hà Nội   - predict: T            , , Chí Minh
# label: Số 97, Thành phố Yên Bái, Yên Bái                                      - predict: T            , , Chí Minh
# label: Số 34J2, Đường DD7-1, Phường Tân Hưng Thuận, Quận 12, TP Hồ Chí Minh   - predict: T            , , Chí Minh
#
# Out of 365 samples:  Mean edit distance: 53.726 Mean normalized edit distance: 0.768
# Epoch 3/60
# 486/486 [==============================] - 547s 1s/step - loss: 179.2336 - val_loss: 166.5419
#
# Epoch 00003: val_loss improved from 181.66886 to 166.54192, saving model to model/best_0.h5
# label: Thôn Phúc Thạnh, Huyện Lâm Hà, Lâm Đồng                                - predict: Số  , , , , H, Quận hành Tà, Hà Minh
# label: 496/99/23 Dương Quảng Hàm, Phường 6, Quận Gò Vấp, TP Hồ Chí Minh       - predict: Số  , , , , H, Quận hành Tà, Hà Minh
# label: 28 Mậu Thân, P.An Nghiệp, Phường An Nghiệp, Quận Ninh Kiều, Cần Thơ    - predict: Số  , , , , H, Quận hành Tà, Hà Minh
#
# Out of 365 samples:  Mean edit distance: 50.592 Mean normalized edit distance: 0.723
# Epoch 4/60
# 486/486 [==============================] - 547s 1s/step - loss: 161.3823 - val_loss: 159.2232
#
# Epoch 00004: val_loss improved from 166.54192 to 159.22317, saving model to model/best_0.h5
# label: Thôn 3, Xã Phùng Xá, Huyện Thạch Thất, Hà Nội                          - predict: Số 1   hưng hưng hưng hưng ân Quận ân TP, Chí Minh
# label: Thông Sơn Đồng, Xã Tiên Phương, Huyện Chương Mỹ, Hà Nội                - predict: Số 1   hưng hưng hưng hưng ân Quận ân TP, Chí Minh
# label: 209 Hoàng Văn Thụ, Phường 7, Thành Phố Vũng Tàu, Bà Rịa - Vũng Tàu     - predict: Số 1   hưng hưng hưng hưng ân Quận ân TP, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 47.734 Mean normalized edit distance: 0.682
# Epoch 5/60
# 486/486 [==============================] - 547s 1s/step - loss: 156.3420 - val_loss: 154.5331
#
# Epoch 00005: val_loss improved from 159.22317 to 154.53315, saving model to model/best_0.h5
# label: Khu 5, xã Tiên Lương, Huyện Cẩm Khê, Phú Thọ                           - predict: Tố   Thư, hưng , nhà, Huệ T TP, Hà Ninh
# label: ấp 1, Xã Đức Hòa Đông, Huyện Đức Hoà, Long An                          - predict: Tố   Thư, hưng , nhà, Huệ T TP, Hà Ninh
# label: Số 3, tổ 8, KP4, Phường Trảng Dài, Thành Phố Biên Hoà, Đồng Nai        - predict: Tố   Thư, hưng , nhà, Huệ T TP, Hà Ninh
#
# Out of 365 samples:  Mean edit distance: 48.893 Mean normalized edit distance: 0.698
# Epoch 6/60
# 486/486 [==============================] - 547s 1s/step - loss: 153.4386 - val_loss: 148.1968
#
# Epoch 00006: val_loss improved from 154.53315 to 148.19681, saving model to model/best_0.h5
# label: Số 4, ngõ 155 Cầu Giấy, Phường Quan Hoa, Quận Cầu Giấy, Hà Nội         - predict: T   , P, P, , , Huyện , TP, Chí Minh
# label: 209/11 Bến Vân Đồn, Tổ 2, phường 05, Quận 4, TP Hồ Chí Minh            - predict: T   , P, P, , , Huyện , TP, Chí Minh
# label: Số 65, phố Viên, Phường Cổ Nhuế 2, Quận Bắc Từ Liêm, Hà Nội            - predict: T   , P, P, , , Huyện , TP, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 50.252 Mean normalized edit distance: 0.718
# Epoch 7/60
# 486/486 [==============================] - 539s 1s/step - loss: 155.6247 - val_loss: 156.9362
#
# Epoch 00007: val_loss did not improve from 148.19681
# label: 24 Đường 96, Phường Thạnh Mỹ Lợi, Quận 2, TP Hồ Chí Minh               - predict: Số 1    , , , , , Quận , TP, Chí Minh
# label: Xã Quảng Tân, Huyện Quảng Xương, Thanh Hoá                             - predict: Số 1    , , , , , Quận , TP, Chí Minh
# label: Khu 2, ấp Thạnh Lợi, TT. AN Thạnh, Tx Thuận An, Bình Dương             - predict: Số 1    , , , , , Quận , TP, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 49.814 Mean normalized edit distance: 0.712
# Epoch 8/60
# 486/486 [==============================] - 536s 1s/step - loss: 154.6166 - val_loss: 146.5773
#
# Epoch 00008: val_loss improved from 148.19681 to 146.57735, saving model to model/best_0.h5
# label: Hùng Vương, Khóm 1, Phường 1, Thành phố Sa Đéc, Đồng Tháp              - predict: Số    , hưng , Tu, Quận  TP, Chí Minh
# label: 160A Hai Bà Trưng, Thành Phố Nam Định, Nam Định                        - predict: Số    , hưng , Tu, Quận  TP, Chí Minh
# label: 23B Khúc Thừa Dụ, Phường Phước Long, Thành Phố Nha Trang, Khánh Hòa    - predict: Số    , hưng , Tu, Quận  TP, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 48.310 Mean normalized edit distance: 0.690
# Epoch 9/60
# 486/486 [==============================] - 535s 1s/step - loss: 153.9091 - val_loss: 148.9092
#
# Epoch 00009: val_loss did not improve from 146.57735
# label: Lô a3 Hàm Nghi, Bình Khánh, Thành phố Long Xuyên, An Giang             - predict: Số        H, Huyện , TP, Hà Ninh
# label: Số 7, ngõ 1/178 phố Thái Hà, Phường Trung Liệt, Quận Đống đa, Hà Nội   - predict: Số        H, Huyện , TP, Hà Ninh
# label: Tổ 2, Xã Yên Bình, Huyện Quang Bình, Hà Giang                          - predict: Số        H, Huyện , TP, Hà Ninh
#
# Out of 365 samples:  Mean edit distance: 51.386 Mean normalized edit distance: 0.734
# Epoch 10/60
# 486/486 [==============================] - 545s 1s/step - loss: 155.2586 - val_loss: 148.3561
#
# Epoch 00010: val_loss did not improve from 146.57735
# label: A44 Nguyễn Trãi, Phường Nguyễn Cư Trinh, Quận 1, TP Hồ Chí Minh        - predict: T    , hưng Tu, Huyện ha TP, Chí Ninh
# label: Số 34J2, Đường DD7-1, Phường Tân Hưng Thuận, Quận 12, TP Hồ Chí Minh   - predict: T    , hưng Tu, Huyện ha TP, Chí Ninh
# label: Số 243/1/10 Tô Hiến Thành, Phường 13, Quận 10, TP Hồ Chí Minh          - predict: T    , hưng Tu, Huyện ha TP, Chí Ninh
#
# Out of 365 samples:  Mean edit distance: 48.855 Mean normalized edit distance: 0.698
# Epoch 11/60
# 486/486 [==============================] - 544s 1s/step - loss: 152.1597 - val_loss: 145.9618
#
# Epoch 00011: val_loss improved from 146.57735 to 145.96185, saving model to model/best_0.h5
# label: Số 9 Phạm Sư Mạnh, Phường Tràng Tiền, Quận Hoàn Kiếm, Hà Nội           - predict: T      , Tu, Huyện a TP, Chí Minh
# label: Số 55 Bình Giã, Phường 8, Thành Phố Vũng Tàu, Bà Rịa - Vũng Tàu        - predict: T      , Tu, Huyện a TP, Chí Minh
# label: Tổ 3 thôn Sáp Mai, Xã Võng La, Huyện Đông Anh, Hà Nội                  - predict: T      , Tu, Huyện a TP, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 51.501 Mean normalized edit distance: 0.736
# Epoch 12/60
# 486/486 [==============================] - 545s 1s/step - loss: 151.8039 - val_loss: 149.1747
#
# Epoch 00012: val_loss did not improve from 145.96185
# label: 458/10/11 Huỳnh Tấn Phát, Phường Bình Thuận, Quận 7, TP Hồ Chí Minh    - predict: 1    , Pưh hưng T, Quận a TP, Hà Minh
# label: 106 Thái Thịnh, Quận Đống đa, Hà Nội                                   - predict: 1    , Pưh hưng T, Quận a TP, Hà Minh
# label: Thị trấn Quốc Oai, Thị trấn Quốc Oai, Huyện Quốc Oai, Hà Nội           - predict: 1    , Pưh hưng T, Quận a TP, Hà Minh
#
# Out of 365 samples:  Mean edit distance: 48.718 Mean normalized edit distance: 0.696
# Epoch 13/60
# 486/486 [==============================] - 543s 1s/step - loss: 151.1902 - val_loss: 146.1829
#
# Epoch 00013: val_loss did not improve from 145.96185
# label: Xóm Cầu, thôn Triều Khúc, Xã Tân Triều, Huyện Thanh Trì, Hà Nội        - predict: Tố   , hưng , , Quận , TP, Cà Ninh
# label: Xóm 6, Xã Mỹ Đồng, Huyện Thuỷ Nguyên, Hải Phòng                        - predict: Tố   , hưng , , Quận , TP, Cà Ninh
# label: Số 02 đường Hưng Đạo Vương, Phường 1, Thành phố Vĩnh Long, Vĩnh Long   - predict: Tố   , hưng , , Quận , TP, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 48.666 Mean normalized edit distance: 0.695
# Epoch 14/60
# 486/486 [==============================] - 547s 1s/step - loss: 153.1534 - val_loss: 148.8762
#
# Epoch 00014: val_loss did not improve from 145.96185
# label: Xã Minh khai, Huyện Vũ Thư, Thái Bình                                  - predict: T   P, hưng  Tu, Quận , TP, Chí Minh
# label: Số 44/2, Khu phố Đông Chiêu, TX Dĩ An, Bình Dương                      - predict: T   P, hưng , Tu, Quận , TP, Chí Minh
# label: 151 Quang Trung, Phường 1, Thành phố Trà Vinh, Trà Vinh                - predict: T   P, hưng , Tu, Quận , TP, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 48.490 Mean normalized edit distance: 0.693
# Epoch 15/60
# 486/486 [==============================] - 537s 1s/step - loss: 150.9373 - val_loss: 148.2013
#
# Epoch 00015: val_loss did not improve from 145.96185
# label: 113 Lê Đình Lý, Phường Vĩnh Trung, Quận Thanh Khê, Đà Nẵng             - predict: T    , Phường  T, Huyện  TP, Cà Ninh
# label: 632 Lã Xuân Oai, Phường Long Trường, Quận 9, TP Hồ Chí Minh            - predict: T    , Phường  T, Huyện  TP, Cà Ninh
# label: Tầm Ngân 2, Lâm Sơn, Huyện Ninh Sơn, Ninh Thuận                        - predict: T    , Phường  T, Huyện  TP, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 48.430 Mean normalized edit distance: 0.692
# Epoch 16/60
# 486/486 [==============================] - 537s 1s/step - loss: 150.5199 - val_loss: 147.3161
#
# Epoch 00016: val_loss did not improve from 145.96185
# label: 311 Điện Biên Phủ, Phường 04, Quận 3, TP Hồ Chí Minh                   - predict: 3   , Thư, hưng T T, Quận T TP H Chí Ninh
# label: 271 đường Đông Bắc, phường Tân Chánh Hiệp, Quận 12, TP Hồ Chí Minh     - predict: 3   , Thư, Phường T T, Quận T TP H Chí Ninh
# label: 155C Thống Nhất, Thị trấn Phan Rí Cửa, Huyện Tuy Phong, Bình Thuận     - predict: 3   , Thư, hưng T T, Quận T TP H Chí Ninh
#
# Out of 365 samples:  Mean edit distance: 47.159 Mean normalized edit distance: 0.674
# Epoch 17/60
# 486/486 [==============================] - 530s 1s/step - loss: 150.1298 - val_loss: 156.7097
#
# Epoch 00017: val_loss did not improve from 145.96185
# label: Xuân Giang, Huyện Nghi Xuân, Hà Tĩnh                                   - predict: Số    , Thư, T H T TP , Cà Ninh
# label: Tổ 11, Thị trấn Sông Mã, Huyện Sông Mã, Sơn La                         - predict: Số    , Thư, T H T TP , Cà Ninh
# label: 186 Hoàng Hoa Thám, Phường 12, Quận Tân Bình, TP Hồ Chí Minh           - predict: Số    , Thư, T  T TP , Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 51.797 Mean normalized edit distance: 0.740
# Epoch 18/60
# 486/486 [==============================] - 533s 1s/step - loss: 158.0069 - val_loss: 144.9921
#
# Epoch 00018: val_loss improved from 145.96185 to 144.99210, saving model to model/best_0.h5
# label: 32 Trần Ngọc Diện, Phường Thảo Điền, Quận 2, TP Hồ Chí Minh            - predict: T    , Phường  T, Huyện T TP , Cà Nội
# label: Thôn Tuyết Diêm, Xã Bình Thuận, Huyện Bình Sơn, Quảng Ngãi             - predict: T    , Phường  T, Huyện T TP, Cà Minh
# label: Tổ dân phố Đông Ba, Phường Thượng Cát, Quận Bắc Từ Liêm, Hà Nội        - predict: T    , Phường  T, Huyện T TP, Cà Minh
#
# Out of 365 samples:  Mean edit distance: 48.340 Mean normalized edit distance: 0.691
# Epoch 19/60
# 486/486 [==============================] - 530s 1s/step - loss: 152.2866 - val_loss: 151.8524
#
# Epoch 00019: val_loss did not improve from 144.99210
# label: B16/14, ấp 2, Xã Bình Chánh, Huyện Bình Chánh, TP Hồ Chí Minh          - predict: 1   , P  , Quận T TP, Chí Minh
# label: 23B Khúc Thừa Dụ, Phường Phước Long, Thành Phố Nha Trang, Khánh Hòa    - predict: 1   , P  , Quận T TP, Chí Minh
# label: 151 Quang Trung, Phường 1, Thành phố Trà Vinh, Trà Vinh                - predict: 1   , P  , Quận T TP, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 50.912 Mean normalized edit distance: 0.727
# Epoch 20/60
# 486/486 [==============================] - 529s 1s/step - loss: 152.5180 - val_loss: 147.5398
#
# Epoch 00020: val_loss did not improve from 144.99210
# label: 149 Trần Phú, Phường Phước Vĩnh, Thành phố Huế, Thừa Thiên - Huế       - predict: T    , Phường hưng T, Huyện T T , Cà Ninh
# label: Thôn 12, Xã Minh Khôi, Huyện Nông Cống, Thanh Hoá                      - predict: T    , Phường hưng T, Huyện T T , Cà Ninh
# label: Đường Hai Bà Trung, Thị trấn Tô Hạp, Huyện Khánh Sơn, Khánh Hòa        - predict: T    , Phường hưng T, Huyện T T , Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 47.868 Mean normalized edit distance: 0.684
# Epoch 21/60
# 486/486 [==============================] - 536s 1s/step - loss: 151.5414 - val_loss: 148.4272
#
# Epoch 00021: val_loss did not improve from 144.99210
# label: Xóm Nam Hoà, Xã Xuất Hóa, Huyện Lạc Sơn, Hòa Bình                      - predict: Số   , Phường  T, Quận T TP, Chí Ninh
# label: 345/28 Trần Hưng Đạo, Phường Cầu Kho, Quận 1, TP Hồ Chí Minh           - predict: Số   , Phường  T, Quận T TP, Chí Ninh
# label: số 449/2E Lê Quang Định, Phường 5, Quận Bình Thạnh, TP Hồ Chí Minh     - predict: Số   , Phường  T, Quận T TP, Chí Ninh
#
# Out of 365 samples:  Mean edit distance: 47.559 Mean normalized edit distance: 0.679
# Epoch 22/60
# 486/486 [==============================] - 543s 1s/step - loss: 151.6883 - val_loss: 146.0200
#
# Epoch 00022: val_loss did not improve from 144.99210
# label: Xã Nghĩa Sơn, Huyện Nghĩa Đàn, Nghệ An                                 - predict: Số   ,  P  , Huyện Ba, TP, Hà Ninh
# label: Lô CII.I, KCN Long Thành, Huyện Long Thành, Đồng Nai                   - predict: Số   ,  P  T, Huyện Ba, TP, Hà Ninh
# label: Số 96, Bạch Đằng, Khu phố 1, Thị Xã Kiến Tường, Long An                - predict: Số   ,  P  T, Huyện Ba, TP, Hà Ninh
#
# Out of 365 samples:  Mean edit distance: 50.507 Mean normalized edit distance: 0.722
# Epoch 23/60
# 486/486 [==============================] - 537s 1s/step - loss: 153.2103 - val_loss: 149.2683
#
# Epoch 00023: val_loss did not improve from 144.99210
# label: Núi Móng, Xã Hoàn Sơn, Huyện Tiên Du, Bắc Ninh                         - predict: T1    P , , Huệ H, TP, Hà Ninh
# label: Số 78/26B Trần Phú, khóm 1, Phường 2, Thành phố Trà Vinh, Trà Vinh     - predict: T1  , ,  P, , Huệ H, TP, Hà Ninh
# label: Thôn Ngọc Sơn 3, Xã Phú Sơn, Huyện Lâm Hà, Lâm Đồng                    - predict: T1    P , , Huệ H, TP, Hà Ninh
#
# Out of 365 samples:  Mean edit distance: 51.732 Mean normalized edit distance: 0.739
# Epoch 24/60
# 486/486 [==============================] - 535s 1s/step - loss: 150.9659 - val_loss: 148.2159
#
# Epoch 00024: val_loss did not improve from 144.99210
# label: 316 Lê Văn Sỹ, Phường 1, Quận Tân Bình, TP Hồ Chí Minh                 - predict: T   T Tư, Tư, Tư, T, Huyện , TP, Chí Ninh
# label: 225A/1, Khu Phố 1A, Phường An Phú, TX Thuận An, Bình Dương             - predict: T   T Tư, Tư, Tư, T, Huyện , TP, Chí Ninh
# label: 130 Nguyễn Trường Tộ, Phường Cẩm Phô, Thành phố Hội An, Quảng Nam      - predict: Số  T Tư Tư, Tư, T, Huyện T, TP, Chí Ninh
#
# Out of 365 samples:  Mean edit distance: 50.008 Mean normalized edit distance: 0.714
# Epoch 25/60
# 486/486 [==============================] - 538s 1s/step - loss: 148.5087 - val_loss: 145.3642
#
# Epoch 00025: val_loss did not improve from 144.99210
# label: 125 đường số 7, khu phố 5, Phường An Phú, Quận 2, TP Hồ Chí Minh       - predict: 1  T P P P T, Quận T, TP, Chí Minh
# label: Xóm 3, Thôn Cấn Hạ, Xã Cấn Hữu, Huyện Quốc Oai, Hà Nội                 - predict: 1  T P P P T, Quận T, TP, Chí Minh
# label: 347/11/29 Lê Văn Thọ, Phường 9, Quận Gò Vấp, TP Hồ Chí Minh            - predict: 1  T P P P T, Quận T, TP, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 50.633 Mean normalized edit distance: 0.723
# Epoch 26/60
# 486/486 [==============================] - 542s 1s/step - loss: 147.8344 - val_loss: 145.8340
#
# Epoch 00026: val_loss did not improve from 144.99210
# label: 309 Bùi Hữu Nghĩa P.01, Phường 1, Quận Bình Thạnh, TP Hồ Chí Minh      - predict: Số   Phường Phường Phường Tu, Quận Tên TP, Cà Ninh
# label: Số 54A/8, Khu phố Đông Nhì, Phường Lái Thiêu, Tx Thuận An, Bình Dương  - predict: Số   Phường Phường Phường Tu, Quận Tên TP, Cà Ninh
# label: 502/7C Hưng Phú, Phường 9, Quận 8, TP Hồ Chí Minh                      - predict: Số   Phường Phường Phường Tu, Quận Tên TP, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 47.833 Mean normalized edit distance: 0.683
# Epoch 27/60
# 486/486 [==============================] - 546s 1s/step - loss: 147.3124 - val_loss: 142.5793
#
# Epoch 00027: val_loss improved from 144.99210 to 142.57929, saving model to model/best_0.h5
# label: Thôn 12, Xã Minh Khôi, Huyện Nông Cống, Thanh Hoá                      - predict: Số  P, P, P Tà, Huyện Tà TP, Hà Ninh
# label: Xóm 6, Xã Giao Yến, Huyện Giao Thuỷ, Nam Định                          - predict: Số  P, P, P Tà, Huyện Tà TP, Hà Ninh
# label: Xuân Giang, Huyện Nghi Xuân, Hà Tĩnh                                   - predict: Số  P, P, P Tà, Huyện Tà TP, Hà Ninh
#
# Out of 365 samples:  Mean edit distance: 50.756 Mean normalized edit distance: 0.725
# Epoch 28/60
# 486/486 [==============================] - 543s 1s/step - loss: 147.1279 - val_loss: 144.1795
#
# Epoch 00028: val_loss did not improve from 142.57929
# label: 130 Nguyễn Trường Tộ, Phường Cẩm Phô, Thành phố Hội An, Quảng Nam      - predict: Số   P P P Tà, Quận Bà TP, Cà Ninh
# label: Thôn Hòa Lâm, Xã Trường Lâm, Huyện Tĩnh Gia, Thanh Hoá                 - predict: Số   P P P Tà, Quận Bà TP, Cà Ninh
# label: Lô CII.I, KCN Long Thành, Huyện Long Thành, Đồng Nai                   - predict: Số   P P P Tà, Quận Bà TP, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 50.959 Mean normalized edit distance: 0.728
# Epoch 29/60
# 486/486 [==============================] - 545s 1s/step - loss: 146.5121 - val_loss: 143.6012
#
# Epoch 00029: val_loss did not improve from 142.57929
# label: SN 24 ấp Hòa Bình, Xã Túc Trưng, Huyện Định Quán, Đồng Nai             - predict: Số  T Phường Phường Phường T, Quận Tên TP, Chí Minh
# label: Thôn Non, Xã Thanh Lưu, Huyện Thanh Liêm, Hà Nam                       - predict: Số  T Phường Phường Phường T, Quận Ba TP, Chí Minh
# label: 345/28 Trần Hưng Đạo, Phường Cầu Kho, Quận 1, TP Hồ Chí Minh           - predict: Số  T Phường Phường Phường T, Quận Tên TP, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 47.244 Mean normalized edit distance: 0.675
# Epoch 30/60
# 486/486 [==============================] - 548s 1s/step - loss: 145.8669 - val_loss: 142.9320
#
# Epoch 00030: val_loss did not improve from 142.57929
# label: Tảo Dương Văn, Huyện Ứng Hoà, Hà Nội                                   - predict: Số  T Tư Phường P Tà, Quận Tà TP, Cà Minh
# label: 38 Khu Hòa Bình, Thành phố Đà Lạt, Lâm Đồng                            - predict: Số  T Tư Phường P Tà, Quận Tà TP, Cà Minh
# label: Thôn 12, Xã Minh Khôi, Huyện Nông Cống, Thanh Hoá                      - predict: Số  T Tư Phường P Tà, Quận Tà TP, Cà Minh
#
# Out of 365 samples:  Mean edit distance: 48.353 Mean normalized edit distance: 0.691
# Epoch 31/60
# 486/486 [==============================] - 547s 1s/step - loss: 145.9600 - val_loss: 145.0243
#
# Epoch 00031: val_loss did not improve from 142.57929
# label: Số 126A Đô Lương, Phường 11, Thành Phố Vũng Tàu, Bà Rịa - Vũng Tàu     - predict: T  T Thư, Phường Tư, Tà, Huyện T TP, Cà Minh
# label: Đội 10, thôn Thượng Dương, Xã Nam Trung, Huyện Nam Sách, Hải Dương     - predict: T  T Thư, Phường Tư, Tà, Huyện T TP, Cà Minh
# label: 94 Tô Hiến Thành, Quận Hai Bà Trưng, Hà Nội                            - predict: T  T Thư, Phường Tư, Tà, Huyện T TP, Cà Minh
#
# Out of 365 samples:  Mean edit distance: 48.170 Mean normalized edit distance: 0.688
# Epoch 32/60
# 486/486 [==============================] - 547s 1s/step - loss: 146.8001 - val_loss: 144.3720
#
# Epoch 00032: val_loss did not improve from 142.57929
# label: Số 166 phố Ngọc Khánh, Phường Giảng Võ, Quận Ba Đình, Hà Nội           - predict: T  T T, P, Tư, Tà, Huyện Tà TP, Hà Ninh
# label: Số 289 Nguyễn Lương Bằng, Phường Văn Đẩu, Quận Kiến An, Hải Phòng      - predict: T  T T, P, Tư, Tà, Huyện Tà TP, Hà Ninh
# label: K89/3 Trần Quang Khải, Phường Thọ Quang, Quận Sơn Trà, Đà Nẵng         - predict: T  T T, P, Tư, Tà, Huyện Tà TP, Hà Ninh
#
# Out of 365 samples:  Mean edit distance: 50.110 Mean normalized edit distance: 0.716
# Epoch 33/60
# 486/486 [==============================] - 548s 1s/step - loss: 146.3622 - val_loss: 144.4022
#
# Epoch 00033: val_loss did not improve from 142.57929
# label: thôn Thanh Mỹ, Xã Phù Lưu, Huyện Lộc Hà, Hà Tĩnh                       - predict: Số   T, Pưh Tà, Quận Tà TP, Cà Minh
# label: Khu CN Đồng Văn, Thị Trấn Đồng Văn, Huyện Duy Tiên, Hà Nam             - predict: Số   T, Pưh Tà, Quận Tà TP, Cà Minh
# label: Thôn 3, Xã Lộc An, Huyện Bảo Lâm, Lâm Đồng                             - predict: Số   T, Pưh Tà, Quận Tà TP, Cà Minh
#
# Out of 365 samples:  Mean edit distance: 50.104 Mean normalized edit distance: 0.716
# Epoch 34/60
# 486/486 [==============================] - 546s 1s/step - loss: 155.3564 - val_loss: 153.2726
#
# Epoch 00034: val_loss did not improve from 142.57929
# label: 66 đường số 33, khu phố 2, Phường Bình An, Quận 2, TP Hồ Chí Minh      - predict: 1  , P, P  , , Quận T T,H Chí Minh
# label: Xã Hợp tiến, Huyện Đông Hưng, Thái Bình                                - predict: 1  , P, P   , Quận T a H Chí Minh
# label: KP Ninh Thịnh, Thị trấn Lộc Ninh, Huyện Lộc Ninh, Bình Phước           - predict: 1  , P, P  , , Quận T a H Chí Minh
#
# Out of 365 samples:  Mean edit distance: 49.945 Mean normalized edit distance: 0.714
# Epoch 35/60
# 486/486 [==============================] - 547s 1s/step - loss: 153.4744 - val_loss: 152.7363
#
# Epoch 00035: val_loss did not improve from 142.57929
# label: ấp 1, Xã Đức Hòa Đông, Huyện Đức Hoà, Long An                          - predict: T   , hưng Tư, T, Quận anh TP, anh Ninh
# label: 38 Lê Hoàng Phái, Phường 17, Quận Gò Vấp, TP Hồ Chí Minh               - predict: T   , Phường , T, Quận anh TP, anh Ninh
# label: Xóm 3, Thôn Cấn Hạ, Xã Cấn Hữu, Huyện Quốc Oai, Hà Nội                 - predict: T   , Phường , T, Quận anh TP, anh Ninh
#
# Out of 365 samples:  Mean edit distance: 48.132 Mean normalized edit distance: 0.688
# Epoch 36/60
# 486/486 [==============================] - 549s 1s/step - loss: 150.1000 - val_loss: 143.7173
#
# Epoch 00036: val_loss did not improve from 142.57929
# label: Tổ 2B, Phố Phú Hà, Phường Phong Châu, Thị Xã Phú Thọ, Phú Thọ          - predict: Số    Tư, P Tư Tà, Huyện Tà, TP, Cà Minh
# label: 190E/2, đường 30/4, Phường Hưng Lợi, Quận Ninh Kiều, Cần Thơ           - predict: Số    Thư, P Tư Tà, Huyện Tà, TP, Cà Minh
# label: 65 Võ Như Hưng, Phường Mỹ An, Quận Ngũ Hành Sơn, Đà Nẵng               - predict: Số    Thư, P Tư Tà, Huyện Tà, TP, Cà Minh
#
# Out of 365 samples:  Mean edit distance: 49.732 Mean normalized edit distance: 0.710
# Epoch 37/60
# 486/486 [==============================] - 547s 1s/step - loss: 146.5948 - val_loss: 143.2602
#
# Epoch 00037: val_loss did not improve from 142.57929
# label: Thôn Non, Xã Thanh Lưu, Huyện Thanh Liêm, Hà Nam                       - predict: Số   P, P T, Tà, Huyện Tà TP, Cà Ninh
# label: Số 523A Thụy Khuê, Phường Bưởi, Quận Tây Hồ, Hà Nội                    - predict: Số   P, P T, Tà, Huyện Tà TP, Cà Ninh
# label: 518/21/27 Võ Văn Kiệt, Phường Cầu Kho, Quận 1, TP Hồ Chí Minh          - predict: Số   P, P T, Tà, Huyện Tà TP, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 50.332 Mean normalized edit distance: 0.719
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# the_inputs (InputLayer)         (None, 1280, 64, 3)  0
# __________________________________________________________________________________________________
# vgg16 (Sequential)              multiple             14714688    the_inputs[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 80, 2048)     0           vgg16[1][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 80, 512)      1049088     reshape[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 80, 512)      0           dense1[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 512, 80)      0           dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512, 80)      6480        permute_2[0][0]
# __________________________________________________________________________________________________
# dim_reduction (Lambda)          (None, 80)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# repeat_vector_2 (RepeatVector)  (None, 512, 80)      0           dim_reduction[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 80, 512)      0           repeat_vector_2[0][0]
# __________________________________________________________________________________________________
# attention_mul (Multiply)        (None, 80, 512)      0           dropout_2[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 80, 512)      1574912     attention_mul[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 80, 512)      1574912     bidirectional_3[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 80, 151)      77463       bidirectional_4[0][0]
# __________________________________________________________________________________________________
# the_labels (InputLayer)         (None, 70)           0
# __________________________________________________________________________________________________
# input_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# label_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           dense2[0][0]
#                                                                  the_labels[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 18,997,543
# Trainable params: 18,997,543
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 1458  Image Loading start...  data/Address/
# Image Loading finish...
# 365  Image Loading start...  data/Address/
# Image Loading finish...
# Epoch 1/60
# 486/486 [==============================] - 556s 1s/step - loss: 197.8657 - val_loss: 191.9581
#
# Epoch 00001: val_loss improved from inf to 191.95808, saving model to model/best_1.h5
# label: Xóm 3, Thôn Cấn Hạ, Xã Cấn Hữu, Huyện Quốc Oai, Hà Nội                 - predict:              , n
# label: Thôn Phúc Thọ, Xã Mai Lâm, Huyện Đông Anh, Hà Nội                      - predict:              , n
# label: Số 243 A, Đê La Thành, Phường Láng Thượng, Quận Đống đa, Hà Nội        - predict:              , n
#
# Out of 365 samples:  Mean edit distance: 55.918 Mean normalized edit distance: 0.799
# Epoch 2/60
# 486/486 [==============================] - 544s 1s/step - loss: 186.0711 - val_loss: 179.4587
#
# Epoch 00002: val_loss improved from 191.95808 to 179.45869, saving model to model/best_1.h5
# label: Tổ 49, khu 11, Phường Thanh Miếu, Thành Phố Việt Trì, Phú Thọ          - predict:              T , Chí Minh
# label: Số 2445 tổ 37, ấp Bông Trang, Xã Thạnh Đức, Huyện Gò Dầu, Tây Ninh     - predict:            Q  T , Chí Minh
# label: Số 44/6 đường Trung Yên 13, Phường Trung Hoà, Quận Cầu Giấy, Hà Nội    - predict:            Q  T , Chí Minh
#
# Out of 365 samples:  Mean edit distance: 53.192 Mean normalized edit distance: 0.760
# Epoch 3/60
# 486/486 [==============================] - 544s 1s/step - loss: 177.7718 - val_loss: 173.5630
#
# Epoch 00003: val_loss improved from 179.45869 to 173.56296, saving model to model/best_1.h5
# label: 553 Tân Kỳ Tân Quý, Phường Tân Quý, Quận Tân phú, TP Hồ Chí Minh       - predict: T          , Quận TP, Cà Minh
# label: Lô số 43-29 Khu CN Phước Đông, Xã Phước Đông, Huyện Gò Dầu, Tây Ninh   - predict: T          , Quận TP, Cà Minh
# label: Số 2/16D Trung Hành 5, Phường Đằng Lâm, Quận Hải An, Hải Phòng         - predict: T          , Quận TP, Cà Minh
#
# Out of 365 samples:  Mean edit distance: 51.885 Mean normalized edit distance: 0.741
# Epoch 4/60
# 486/486 [==============================] - 541s 1s/step - loss: 164.7236 - val_loss: 156.7250
#
# Epoch 00004: val_loss improved from 173.56296 to 156.72502, saving model to model/best_1.h5
# label: 2A Cư Xã Phúc Hải, Phường Tân Phong, Thành phố Biên Hoà, Đồng Nai      - predict: 3       , , Quận  TP, Chí Minh
# label: Tiểu khu 3, Thị trấn Đồng Lê, Huyện Tuyên Hoá, Quảng Bình              - predict: 3       , , Quận  TP, Chí Minh
# label: Thôn Thuận Hưng, Xã Thuận Hạnh, Huyện Đắk Song, Đắk Nông               - predict: 3       , , Quận  TP, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 51.367 Mean normalized edit distance: 0.734
# Epoch 5/60
# 486/486 [==============================] - 540s 1s/step - loss: 158.5206 - val_loss: 155.0196
#
# Epoch 00005: val_loss improved from 156.72502 to 155.01962, saving model to model/best_1.h5
# label: thôn Phước Lợi, Xã Phước Đồng, Thành Phố Nha Trang, Khánh Hòa          - predict: Số       , Quận Quận , TP, Chí Minh
# label: 7A/31 Thành Thái, Phường 14, Quận 10, TP Hồ Chí Minh                   - predict: Số       , Tu, Quận , TP, Chí Minh
# label: Số 4, ngõ 347 Nguyễn Khang, Phường Yên Hoà, Quận Cầu Giấy, Hà Nội      - predict: Số       , Quận Quận  TP, Chí Minh
#
# Out of 365 samples:  Mean edit distance: 50.625 Mean normalized edit distance: 0.723
# Epoch 6/60
# 486/486 [==============================] - 546s 1s/step - loss: 154.3921 - val_loss: 151.0261
#
# Epoch 00006: val_loss improved from 155.01962 to 151.02612, saving model to model/best_1.h5
# label: Thôn Đọi Nhất, xã Đọi Sơn, Xã Đọi Sơn, Huyện Duy Tiên, Hà Nam          - predict:        , Quận  TP, Cà Minh
# label: Thôn Quý Khê, Xã Cẩm Hoàng, Huyện Cẩm Giàng, Hải Dương                 - predict:        , Quận  TP, Cà Minh
# label: Số 39 đường số 2, Phường Trường Thọ, Quận Thủ Đức, TP Hồ Chí Minh      - predict:        , Quận  TP, Cà Minh
#
# Out of 365 samples:  Mean edit distance: 51.803 Mean normalized edit distance: 0.740
# Epoch 7/60
# 486/486 [==============================] - 546s 1s/step - loss: 154.6217 - val_loss: 153.4104
#
# Epoch 00007: val_loss did not improve from 151.02612
# label: 1144/14 Lê Đức Thọ, Phường 13, Quận Gò Vấp, TP Hồ Chí Minh             - predict: Số      , , Huyện  TP, Cà Ninh
# label: 50 Phan Chu Trinh, Phường Hải Châu I, Quận Hải Châu, Đà Nẵng           - predict: Số      , , Huyện , TP, Cà Ninh
# label: 58-Nguyễn Trường Tộ, Phường Ninh Hiệp, Thị xã Ninh Hoà, Khánh Hòa      - predict: Số      , , Huyện , TP, Cà Ninh
#
# Out of 365 samples:  Mean edit distance: 51.285 Mean normalized edit distance: 0.733
# Epoch 8/60
# 355/486 [====================>.........] - ETA: 2:14 - loss: 153.0356
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-0631f29d255c> in <module>()
#       9 args = [xtrain, xlabel, xepochs, xbatch_size, xlr, finetune, name]
#      10
# ---> 11 train(xtrain, xlabel, xepochs, xbatch_size, xlr, finetune, name)
#
# <ipython-input-3-dffee1c8f362> in train(datapath, labelpath, epochs, batch_size, lr, finetune, name)
#      79     kfold = list(KFold(nsplits, random_state=2018).split(nfiles))
#      80     for idx in range(nsplits):
# ---> 81         train_kfold(idx, kfold, datapath, labelpath, epochs, batch_size, lr, finetune, name)
#
# <ipython-input-3-dffee1c8f362> in train_kfold(idx, kfold, datapath, labelpath, epochs, batch_size, lr, finetune, name)
#      70                     callbacks=[ckp, vis, earlystop],
#      71                     validation_data=valid_generator.next_batch(),
# ---> 72                     validation_steps=int(len(valid_idx) / batch_size))
#      73
#      74 def train(datapath, labelpath, epochs, batch_size, lr, finetune=False, name='model'):
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
datapath = 'data/Address/'
labelpath = 'data/labels.json'
epochs = 31
batch_size = 3
lr = 0.00001 
finetune = 0
name = 'best'

args = [datapath, labelpath, epochs, batch_size, lr, finetune, name]

#train(xtrain, xlabel, xepochs, xbatch_size, xlr, finetune, name)
